# %% [markdown]
# - **IMPORTACIÓN, EXTRACCIÓN Y CONVERSION DE LOS DATOS DE METADATA**

# %%
import pandas as pd

# %%
import os
import json

def convert_json_to_parquet(input_folder, output_folder):
    # Crear la carpeta de salida si no existe
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Listar todos los archivos en la carpeta de entrada
    files = os.listdir(input_folder)
    
    for file in files:
        if file.endswith('.json'):
            file_path = os.path.join(input_folder, file)
            try:
                # Leer el archivo JSON línea por línea
                with open(file_path, 'r') as f:
                    data = [json.loads(line) for line in f]
                
                # Convertir a DataFrame
                df = pd.DataFrame(data)
                
                # Convertir a Parquet
                output_file_path = os.path.join(output_folder, file.replace('.json', '.parquet'))
                df.to_parquet(output_file_path)
                print('Converted', file, 'to', output_file_path)
            except ValueError as e:
                print('Error processing', file, ':', e)

# Llamar a la función
convert_json_to_parquet('metadata-sitios', 'metadata-sitios-parquet')
# Out:
# Converted 1.json to metadata-sitios-parquet\1.parquet
# Converted 10.json to metadata-sitios-parquet\10.parquet
# Converted 11.json to metadata-sitios-parquet\11.parquet
# Converted 2.json to metadata-sitios-parquet\2.parquet
# Converted 3.json to metadata-sitios-parquet\3.parquet
# Converted 4.json to metadata-sitios-parquet\4.parquet
# Converted 5.json to metadata-sitios-parquet\5.parquet
# Converted 6.json to metadata-sitios-parquet\6.parquet
# Converted 7.json to metadata-sitios-parquet\7.parquet
# Converted 8.json to metadata-sitios-parquet\8.parquet
# Converted 9.json to metadata-sitios-parquet\9.parquet

# %%
def merge_parquet_files(input_folder):
    # Listar todos los archivos en la carpeta de entrada
    files = os.listdir(input_folder)
    
    # Filtrar solo los archivos Parquet
    parquet_files = [file for file in files if file.endswith('.parquet')]
    
    # Leer y concatenar todos los archivos Parquet en un solo DataFrame
    dataframes = []
    for file in parquet_files:
        file_path = os.path.join(input_folder, file)
        df = pd.read_parquet(file_path)
        dataframes.append(df)
    
    # Concatenar todos los DataFrames
    merged_df = pd.concat(dataframes, ignore_index=True)
    
    return merged_df

# Llamar a la función
merged_df = merge_parquet_files('metadata-sitios-parquet')
merged_df.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 1   [Textile exporter]         4.5               6  None
# 2  [Korean restaurant]         4.4              18  None
# 3       [Fabric store]         3.3               6  None
# 4       [Fabric store]         4.3               7  None
#
#                                                hours  \
# 0  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1                                               None
# 2  [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 3  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
#
#                                                 MISC              state  \
# 0  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 6PM
# 1                                               None           Open now
# 2  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 6PM
# 3  {'Accessibility': None, 'Activities': None, 'A...  Open ⋅ Closes 5PM
# 4  {'Accessibility': None, 'Activities': None, 'A...  Open ⋅ Closes 5PM
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1  [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 2  [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 3  [0x80c2c8811477253f:0x23a8a492df1918f7, 0x80c2...
# 4  [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# - Filtrar por "Starbucks"

# %%
# Crear una serie booleana que indique las filas que contienen 'starbucks' (case-insensitive)
starbucks_matches = merged_df['name'].str.contains('Starbucks', case=False)

# Contar el número de valores verdaderos (ocurrencias)
starbucks_count = starbucks_matches.sum()

# Imprima el recuento
print(starbucks_count)
# Out:
# 3499

# %%
#Filtrar el dataframe solo para las filas que contengan "starbucks" en la columna "name"
merged_df['name'] = merged_df['name'].apply(lambda x: x if x is not None else [])


starbucks_merged_df = merged_df[merged_df['name'].apply(lambda x: 'Starbucks' in x)]

# Inspeccionar las primeras filas del DataFrame filtrado
starbucks_merged_df.head(10)
# Out:
#             name                                            address  \
# 2759   Starbucks      Starbucks, 777 Coushatta Dr, Kinder, LA 70648
# 4689   Starbucks  Starbucks, 1021 S Highline Pl, Sioux Falls, SD...
# 6767   Starbucks  Starbucks, 3285 Crosspark Rd, Coralville, IA 5...
# 8853   Starbucks  Starbucks, 9600 Falls of Neuse Rd, Raleigh, NC...
# 9937   Starbucks  Starbucks, Exit 326 Eastbound, Milepost 324, 6...
# 11372  Starbucks   Starbucks, 2340 Legge Blvd, Winchester, VA 22601
# 11964  Starbucks  Starbucks, Newport FS Town Center, Menifee, CA...
# 12625  Starbucks      Starbucks, 400 Bridge St, Clarkston, WA 99403
# 17937  Starbucks          Starbucks, 8000 York Rd, Towson, MD 21252
# 17975  Starbucks        Starbucks, 3333 Spartan Rd, Olney, MD 20832
#
#                                      gmap_id  \
# 2759   0x863b157fa8b51d01:0x1e4fe1352f3c5410
# 4689   0x878eb38c36597305:0xcbf23f742073a95a
# 6767   0x87e445ce7b5d0903:0x64ef7bd0dd566918
# 8853   0x89ac57caf94e3281:0x8d8e0a9bcb3797f4
# 9937   0x89c693867ed7de97:0x3f76a336d8d512e0
# 11372  0x89b5eee6325d8599:0xa8b3b69fd1331fe6
# 11964  0x80dc9dcbf3081853:0x431bcc44582ddf42
# 12625  0x54a1cac671b3294b:0x4c2626802f30ae27
# 17937  0x89c80fbcae20f7ed:0xb468795a07685c27
# 17975  0x89b7d1197df7866f:0xdbd6df3a25b26f97
#
#                                              description   latitude  \
# 2759   Seattle-based coffeehouse chain known for its ...  30.544849
# 4689   Seattle-based coffeehouse chain known for its ...  43.539009
# 6767   Seattle-based coffeehouse chain known for its ...  41.721587
# 8853   Seattle-based coffeehouse chain known for its ...  35.904970
# 9937   Seattle-based coffeehouse chain known for its ...  40.083163
# 11372  Seattle-based coffeehouse chain known for its ...  39.154300
# 11964                                               None  33.684600
# 12625  Seattle-based coffeehouse chain known for its ...  46.421219
# 17937  Seattle-based coffeehouse chain known for its ...  39.394018
# 17975  Seattle-based coffeehouse chain known for its ...  39.150387
#
#         longitude                                         category  \
# 2759   -92.813979  [Coffee shop, Cafe, Coffee store, Espresso bar]
# 4689   -96.654927  [Coffee shop, Cafe, Coffee store, Espresso bar]
# 6767   -91.604530  [Coffee shop, Cafe, Coffee store, Espresso bar]
# 8853   -78.601090  [Coffee shop, Cafe, Coffee store, Espresso bar]
# 9937   -75.440100  [Coffee shop, Cafe, Coffee store, Espresso bar]
# 11372  -78.167358  [Coffee shop, Cafe, Coffee store, Espresso bar]
# 11964 -117.179018                                    [Coffee shop]
# 12625 -117.043070                                    [Coffee shop]
# 17937  -76.606298                                    [Coffee shop]
# 17975  -77.065087  [Coffee shop, Cafe, Coffee store, Espresso bar]
#
#        avg_rating  num_of_reviews price  \
# 2759          3.3               3    $$
# 4689          3.2              18    $$
# 6767          4.0              15    $$
# 8853          4.5               8    $$
# 9937          2.9              15    $$
# 11372         4.3              18    $$
# 11964         4.5              26  None
# 12625         4.1              13    $$
# 17937         4.1               4    $$
# 17975         4.2              18    $$
#
#                                                    hours  \
# 2759   [[Thursday, 7AM–7PM], [Friday, 7AM–7PM], [Satu...
# 4689   [[Wednesday, 7AM–8PM], [Thursday, 7AM–8PM], [F...
# 6767   [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
# 8853   [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
# 9937   [[Wednesday, 7AM–7PM], [Thursday, 7AM–7PM], [F...
# 11372  [[Wednesday, 8AM–9PM], [Thursday, 8AM–9PM], [F...
# 11964  [[Wednesday, 5AM–9PM], [Thursday, 5AM–9PM], [F...
# 12625  [[Wednesday, 5AM–6:30PM], [Thursday, 5AM–6:30P...
# 17937  [[Wednesday, 8AM–7PM], [Thursday, 8AM–7PM], [F...
# 17975  [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
#
#                                                     MISC  \
# 2759   {'Accessibility': ['Wheelchair accessible entr...
# 4689   {'Accessibility': ['Wheelchair accessible entr...
# 6767   {'Accessibility': ['Wheelchair accessible entr...
# 8853   {'Accessibility': ['Wheelchair accessible entr...
# 9937   {'Accessibility': ['Wheelchair accessible entr...
# 11372  {'Accessibility': ['Wheelchair accessible entr...
# 11964  {'Accessibility': ['Wheelchair accessible entr...
# 12625  {'Accessibility': ['Wheelchair accessible entr...
# 17937  {'Accessibility': ['Wheelchair accessible entr...
# 17975  {'Accessibility': ['Wheelchair accessible entr...
#
#                                    state  \
# 2759                  Closed ⋅ Opens 7AM
# 4689              Closed ⋅ Opens 7AM Thu
# 6767   Closes soon ⋅ 8PM ⋅ Opens 6AM Thu
# 8853                   Open ⋅ Closes 8PM
# 9937                   Open ⋅ Closes 7PM
# 11372                  Open ⋅ Closes 9PM
# 11964                  Open ⋅ Closes 9PM
# 12625               Open ⋅ Closes 6:30PM
# 17937                 Closed ⋅ Opens 8AM
# 17975                 Closed ⋅ Opens 6AM
#
#                                         relative_results  \
# 2759   [0x863b14b4c7136f01:0xb153879cf4c9fd95, 0x863b...
# 4689   [0x878eb38bf781ca91:0xc0710c30260e2429, 0x878e...
# 6767   [0x87e441aeb4a25f27:0xb13d1072372fbdd1, 0x87e4...
# 8853                                                None
# 9937   [0x89c6944bb5799605:0x16d89163c48f625a, 0x89c6...
# 11372  [0x89b5efb977f22785:0x1f1094c8a1599fed, 0x89b5...
# 11964                                               None
# 12625  [0x54a1cac2869f2207:0x448085c25a8e4f7f, 0x54a1...
# 17937  [0x89c80fa598b5e1e3:0xe1a549a39e5cc962, 0x89c8...
# 17975  [0x89b7d119f6fe318f:0x7c4c059aad2fefac, 0x89b7...
#
#                                                      url
# 2759   https://www.google.com/maps/place//data=!4m2!3...
# 4689   https://www.google.com/maps/place//data=!4m2!3...
# 6767   https://www.google.com/maps/place//data=!4m2!3...
# 8853   https://www.google.com/maps/place//data=!4m2!3...
# 9937   https://www.google.com/maps/place//data=!4m2!3...
# 11372  https://www.google.com/maps/place//data=!4m2!3...
# 11964  https://www.google.com/maps/place//data=!4m2!3...
# 12625  https://www.google.com/maps/place//data=!4m2!3...
# 17937  https://www.google.com/maps/place//data=!4m2!3...
# 17975  https://www.google.com/maps/place//data=!4m2!3...

# %%
import os
output_folder = 'metadata-sitios-parquet'
output_file = os.path.join(output_folder, 'Metadata_Starbucks.parquet')

# Crear la carpeta de salida si no existe
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Convertir las listas en las columnas a cadenas
for column in starbucks_merged_df.columns:
    if starbucks_merged_df[column].apply(lambda x: isinstance(x, list)).any():
        starbucks_merged_df[column] = starbucks_merged_df[column].apply(lambda x: str(x) if isinstance(x, list) else x)

# Exportar el DataFrame combinado a un archivo Parquet
starbucks_merged_df.to_parquet(output_file)
print('Dataframe mergeado exportado a', output_file)
# Out:
# Dataframe mergeado exportado a metadata-sitios-parquet\Metadata_Starbucks.parquet

# %% [markdown]
# - Filtrar por "Dunkin"

# %%
# Crear una serie booleana que indique las filas que contienen 'starbucks' (case-insensitive)
dunkin_matches = merged_df['name'].str.contains('Dunkin', case=False)

# Contar el número de valores verdaderos (ocurrencias)
dunkin_matches_count = dunkin_matches.sum()

# Imprima el recuento
print(dunkin_matches_count)
# Out:
# 2182

# %%
#Filtrar el dataframe solo para las filas que contengan "starbucks" en la columna "name"
merged_df['name'] = merged_df['name'].apply(lambda x: x if x is not None else [])


dunkin_merged_df = merged_df[merged_df['name'].apply(lambda x: 'Dunkin' in x)]

# Inspeccionar las primeras filas del DataFrame filtrado
dunkin_merged_df.head(10)
# Out:
#                 name                                            address  \
# 535    Dunkin Bridge                      Dunkin Bridge, Yale, OK 74085
# 742          Dunkin'          Dunkin', 4008 Bell Blvd, Queens, NY 11361
# 2139          Dunkin  Dunkin, 1132 Mineral Spring Ave, North Provide...
# 7003         Dunkin'  Dunkin', 525 Pleasant Valley Ave, Mt Laurel To...
# 14129        Dunkin'  Dunkin', In Stop & Shop, 380 Main Ave, Norwalk...
# 20538        Dunkin'       Dunkin', 205 Wheeler Rd, Hauppauge, NY 11788
# 25600        Dunkin'  Dunkin', In Walmart, 615 Meadow St, Littleton,...
# 27108  Dunkin Bridge                      Dunkin Bridge, Yale, OK 74085
# 27315        Dunkin'          Dunkin', 4008 Bell Blvd, Queens, NY 11361
# 28712         Dunkin  Dunkin, 1132 Mineral Spring Ave, North Provide...
#
#                                      gmap_id  \
# 535    0x87b16b690c76dc71:0xdf78fabac3bdaa5f
# 742    0x89c261f60bdf13db:0x38da730e4687a97b
# 2139   0x89e44489cbeccc03:0xd3b75bf4e9a39824
# 7003   0x89c1352001dc66d1:0xb8ca54f815dbb1bf
# 14129  0x89e81daec8b2f445:0x6fb1428534e11ad0
# 20538  0x89e8311761d696e5:0xdcd22b9e69edba24
# 25600   0x4cb468bf747bd0a1:0xa7d59087af3aa8a
# 27108  0x87b16b690c76dc71:0xdf78fabac3bdaa5f
# 27315  0x89c261f60bdf13db:0x38da730e4687a97b
# 28712  0x89e44489cbeccc03:0xd3b75bf4e9a39824
#
#                                              description   latitude  \
# 535                                                 None  36.044505
# 742    Long-running chain serving signature breakfast...  40.763985
# 2139   Long-running chain serving signature breakfast...  41.867869
# 7003   Long-running chain serving signature breakfast...  39.948164
# 14129  Long-running chain serving signature breakfast...  41.140586
# 20538  Long-running chain serving signature breakfast...  40.803367
# 25600  Long-running chain serving signature breakfast...  44.304694
# 27108                                               None  36.044505
# 27315  Long-running chain serving signature breakfast...  40.763985
# 28712  Long-running chain serving signature breakfast...  41.867869
#
#        longitude                                           category  \
# 535   -96.820584                                           [Bridge]
# 742   -73.771430  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 2139  -71.428798  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 7003  -74.949908  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 14129 -73.423947  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 20538 -73.212653  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 25600 -71.798561  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 27108 -96.820584                                           [Bridge]
# 27315 -73.771430  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 28712 -71.428798  [Coffee shop, Bagel shop, Bakery, Breakfast re...
#
#        avg_rating  num_of_reviews price  \
# 535           5.0               5  None
# 742           3.5               8     $
# 2139          3.9               8     $
# 7003          4.1               8     $
# 14129         3.9              15     $
# 20538         3.9              16     $
# 25600         2.9              27     $
# 27108         5.0               5  None
# 27315         3.5               8     $
# 28712         3.9               8     $
#
#                                                    hours  \
# 535                                                 None
# 742    [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 2139                                                None
# 7003   [[Wednesday, 5AM–8PM], [Thursday, 5AM–8PM], [F...
# 14129  [[Wednesday, 6AM–8PM], [Thursday, 6AM–8PM], [F...
# 20538  [[Wednesday, 5AM–8PM], [Thursday, 5AM–8PM], [F...
# 25600                                               None
# 27108                                               None
# 27315  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 28712                                               None
#
#                                                     MISC  \
# 535                                                 None
# 742    {'Accessibility': ['Wheelchair accessible entr...
# 2139   {'Accessibility': ['Wheelchair accessible entr...
# 7003   {'Accessibility': ['Wheelchair accessible entr...
# 14129  {'Accessibility': ['Wheelchair accessible entr...
# 20538  {'Accessibility': ['Wheelchair accessible entr...
# 25600  {'Accessibility': ['Wheelchair accessible entr...
# 27108                                               None
# 27315  {'Accessibility': ['Wheelchair accessible entr...
# 28712  {'Accessibility': ['Wheelchair accessible entr...
#
#                                    state  \
# 535                                 None
# 742                    Open ⋅ Closes 7PM
# 2139                                None
# 7003   Closes soon ⋅ 8PM ⋅ Opens 5AM Thu
# 14129                  Open ⋅ Closes 8PM
# 20538                 Closed ⋅ Opens 5AM
# 25600                               None
# 27108                               None
# 27315                  Open ⋅ Closes 7PM
# 28712                               None
#
#                                         relative_results  \
# 535    [0x87b0dfddc4e496ad:0x295ee748aa3bdf41, 0x87b1...
# 742    [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 2139   [0x89e445c7c4df7a27:0x43ad29caf35d3302, 0x89e4...
# 7003                                                None
# 14129  [0x89e81dae24931a4f:0x90566a736c61470d, 0x89e8...
# 20538                                               None
# 25600  [0x4cb46f2dffbff059:0x2726c2de459ce710, 0x4cb4...
# 27108  [0x87b0dfddc4e496ad:0x295ee748aa3bdf41, 0x87b1...
# 27315  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 28712  [0x89e445c7c4df7a27:0x43ad29caf35d3302, 0x89e4...
#
#                                                      url
# 535    https://www.google.com/maps/place//data=!4m2!3...
# 742    https://www.google.com/maps/place//data=!4m2!3...
# 2139   https://www.google.com/maps/place//data=!4m2!3...
# 7003   https://www.google.com/maps/place//data=!4m2!3...
# 14129  https://www.google.com/maps/place//data=!4m2!3...
# 20538  https://www.google.com/maps/place//data=!4m2!3...
# 25600  https://www.google.com/maps/place//data=!4m2!3...
# 27108  https://www.google.com/maps/place//data=!4m2!3...
# 27315  https://www.google.com/maps/place//data=!4m2!3...
# 28712  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Obtener el número de filas del DataFrame
num_filas = dunkin_merged_df.shape[0]

# Imprimir el número de filas
print('El DataFrame dunkin_merged_df tiene', num_filas, 'filas.')
# Out:
# El DataFrame dunkin_merged_df tiene 2180 filas.

# %%
import os
output_folder = 'metadata-sitios-parquet'
output_file = os.path.join(output_folder, 'Metadata_Dunkin.parquet')

# Crear la carpeta de salida si no existe
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Convertir las listas en las columnas a cadenas
for column in dunkin_merged_df.columns:
    if dunkin_merged_df[column].apply(lambda x: isinstance(x, list)).any():
        dunkin_merged_df[column] = dunkin_merged_df[column].apply(lambda x: str(x) if isinstance(x, list) else x)

# Exportar el DataFrame combinado a un archivo Parquet
dunkin_merged_df.to_parquet(output_file)
print('Dataframe mergeado exportado a', output_file)
# Out:
# Dataframe mergeado exportado a metadata-sitios-parquet\Metadata_Dunkin.parquet

# %% [markdown]
# - **IMPORTACIÓN, EXTRACCIÓN Y CONVERSIÓN DE LOS DATOS DE REVIEWS-ESTADOS.**

# %% [markdown]
# -Aplicamos una funcion para convertir los archivos a parquet de cada carpeta de reviews-estados(los 51 estados), creamos una carpeta nueva y almacenamos alli los mismos.

# %%
import os
import pandas as pd
import json

def direct_json_to_parquet():
    # Crear la carpeta de destino si no existe
    output_folder = 'reviews-estados-parquet'
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Listar todas las carpetas dentro de 'reviews-estados'
    base_folder = 'reviews-estados'
    folders = [f for f in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, f))]
    
    for folder in folders:
        folder_path = os.path.join(base_folder, folder)
        # Listar archivos JSON en la carpeta
        json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]
        
        # Leer y combinar archivos JSON
        df_list = []
        for json_file in json_files:
            file_path = os.path.join(folder_path, json_file)
            with open(file_path, 'r') as file:
                data = [json.loads(line) for line in file if line.strip()]
            df = pd.DataFrame(data)
            df_list.append(df)
        
        # Concatenar todos los DataFrames
        combined_df = pd.concat(df_list, ignore_index=True)
        
        # Convertir a Parquet y guardar
        parquet_file = os.path.join(output_folder, folder + '.parquet')
        combined_df.to_parquet(parquet_file)
        print('Converted and saved:', parquet_file)

# Ejecutar la función
direct_json_to_parquet()

# %% [markdown]
# - **MERGE DE LA DATA DE METADATA CON REVIEWS-ESTADOS PARA STARBUCKS Y DUNKIN.**

# %% [markdown]
# -Aplicamos una funcion, para mergear todos lo archivos parquet de los reviews de cada estado con la data filtrada de starbucks de metadata. Lo almacenamos en una carpeta nueva 'Starbucks-Google-Reviews'.

# %%
import os
import pandas as pd

def merge_with_metadata_and_save():
    # Cargar el dataset de metadata
    metadata_starbucks_df = pd.read_parquet('metadata-sitios-parquet/Metadata_Starbucks.parquet')
    
    # Crear la carpeta de destino si no existe
    output_folder = 'Starbucks-Google-Reviews'
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Listar todos los archivos Parquet en la carpeta 'reviews-estados-prueba'
    input_folder = 'reviews-estados-parquet'
    parquet_files = [f for f in os.listdir(input_folder) if f.endswith('.parquet')]
    
    for parquet_file in parquet_files:
        file_path = os.path.join(input_folder, parquet_file)
        
        # Cargar el archivo Parquet
        reviews_df = pd.read_parquet(file_path)
        
        # Joinear los datasets en 'gmap_id'
        merged_df = pd.merge(metadata_starbucks_df, reviews_df, on='gmap_id')
        
        # Generar el nombre del archivo de salida basado en el nombre del archivo de entrada
        state_name = parquet_file.replace('.parquet', '').replace('review-', '').replace('_', ' ')
        output_file = os.path.join(output_folder, state_name + ' Starbucks Reviews.parquet')
        
        # Guardar el DataFrame resultante en un nuevo archivo Parquet
        merged_df.to_parquet(output_file)
        print('Merged and saved:', output_file)

# Ejecutar la función
merge_with_metadata_and_save()
# Out:
# Merged and saved: Starbucks-Google-Reviews\Alabama Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Alaska Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Arizona Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Arkansas Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\California Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Colorado Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Connecticut Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Delaware Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\District of Columbia Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Florida Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Georgia Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Hawaii Starbucks Reviews.parquet
# Merged and saved: Starbucks-Google-Reviews\Idaho Starbucks Reviews.parquet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 35
#      32         print('Merged and saved:', output_file)
#      34 # Ejecutar la función
# ---> 35 merge_with_metadata_and_save()
#
# Cell In[79], line 21, in merge_with_metadata_and_save()
#      18 file_path = os.path.join(input_folder, parquet_file)
#      20 # Cargar el archivo Parquet
# ---> 21 reviews_df = pd.read_parquet(file_path)
#      23 # Joinear los datasets en 'gmap_id'
#      24 merged_df = pd.merge(metadata_starbucks_df, reviews_df, on='gmap_id')
#
# File c:\Users\zimme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\Users\zimme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:281, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
# --> 281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#     284         result = result._as_manager("array", copy=False)
#
# File c:\Users\zimme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\array.pxi:872, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File c:\Users\zimme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\table.pxi:4904, in pyarrow.lib.Table._to_pandas()
#
# File c:\Users\zimme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\pandas_compat.py:779, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     776 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     778 column_names = table.column_names
# --> 779 result = pa.lib.table_to_blocks(options, table, categories,
#     780                                 list(ext_columns_dtypes.keys()))
#     781 if _pandas_api.is_ge_v3():
#     782     from pandas.api.internals import create_dataframe_from_blocks
#
# KeyboardInterrupt:

# %% [markdown]
# -Mergear todos los parquet de Starbucks reviews y guardarlo en un unico archivo parquet en la carpeta "Starbucks-Google-Reviews".

# %%
import os
import pandas as pd

def merge_all_reviews():
    # Listar todos los archivos Parquet en la carpeta 'Starbucks-Google-Reviews'
    input_folder = 'Starbucks-Google-Reviews'
    parquet_files = [f for f in os.listdir(input_folder) if f.endswith('.parquet')]
    
    # Leer y combinar todos los archivos Parquet
    df_list = []
    for parquet_file in parquet_files:
        file_path = os.path.join(input_folder, parquet_file)
        df = pd.read_parquet(file_path)
        df_list.append(df)
    
    # Concatenar todos los DataFrames
    combined_df = pd.concat(df_list, ignore_index=True)
    
    # Guardar el DataFrame combinado en un solo archivo Parquet
    output_file = os.path.join(input_folder, 'Google_Starbucks_Reviews.parquet')
    combined_df.to_parquet(output_file)
    print('Google_Starbucks_Reviews guardado en:', output_file)

# Ejecutar la función
merge_all_reviews()

# %% [markdown]
# -Hacemos los mismos pasos pero con "dunkin".

# %%
import os
import pandas as pd

def merge_with_metadata_and_save():
    # Cargar el dataset de metadata
    metadata_starbucks_df = pd.read_parquet('metadata-sitios-parquet/Metadata_Dunkin.parquet')
    
    # Crear la carpeta de destino si no existe
    output_folder = 'Dunkin-Google-Reviews'
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Listar todos los archivos Parquet en la carpeta 'reviews-estados-prueba'
    input_folder = 'reviews-estados-parquet'
    parquet_files = [f for f in os.listdir(input_folder) if f.endswith('.parquet')]
    
    for parquet_file in parquet_files:
        file_path = os.path.join(input_folder, parquet_file)
        
        # Cargar el archivo Parquet
        reviews_df = pd.read_parquet(file_path)
        
        # Joinear los datasets en 'gmap_id'
        merged_df = pd.merge(metadata_starbucks_df, reviews_df, on='gmap_id')
        
        # Generar el nombre del archivo de salida basado en el nombre del archivo de entrada
        state_name = parquet_file.replace('.parquet', '').replace('review-', '').replace('_', ' ')
        output_file = os.path.join(output_folder, state_name + ' Dunkin Reviews.parquet')
        
        # Guardar el DataFrame resultante en un nuevo archivo Parquet
        merged_df.to_parquet(output_file)
        print('Merged and saved:', output_file)

# Ejecutar la función
merge_with_metadata_and_save()
# Out:
# Merged and saved: Dunkin-Google-Reviews\Alabama Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Alaska Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Arizona Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Arkansas Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\California Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Colorado Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Connecticut Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Delaware Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\District of Columbia Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Florida Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Georgia Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Hawaii Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Idaho Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Illinois Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Indiana Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Iowa Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Kansas Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Kentucky Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Louisiana Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Maine Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Maryland Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Massachusetts Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Michigan Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Minnesota Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Mississippi Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Missouri Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Montana Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Nebraska Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Nevada Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\New Hampshire Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\New Jersey Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\New Mexico Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\New York Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\North Carolina Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\North Dakota Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Ohio Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Oklahoma Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Oregon Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Pennsylvania Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Rhode Island Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\South Carolina Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\South Dakota Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Tennessee Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Texas Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Utah Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Vermont Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Virginia Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Washington Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\West Virginia Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Wisconsin Dunkin Reviews.parquet
# Merged and saved: Dunkin-Google-Reviews\Wyoming Dunkin Reviews.parquet

# %%
import os
import pandas as pd

def merge_all_reviews():
    # Listar todos los archivos Parquet en la carpeta 'Starbucks-Google-Reviews'
    input_folder = 'Dunkin-Google-Reviews'
    parquet_files = [f for f in os.listdir(input_folder) if f.endswith('.parquet')]
    
    # Leer y combinar todos los archivos Parquet
    df_list = []
    for parquet_file in parquet_files:
        file_path = os.path.join(input_folder, parquet_file)
        df = pd.read_parquet(file_path)
        df_list.append(df)
    
    # Concatenar todos los DataFrames
    combined_df = pd.concat(df_list, ignore_index=True)
    
    # Guardar el DataFrame combinado en un solo archivo Parquet
    output_file = os.path.join(input_folder, 'Google_Dunkin_Reviews.parquet')
    combined_df.to_parquet(output_file)
    print('Google_Dunkin_Reviews guardado en:', output_file)

# Ejecutar la función
merge_all_reviews()
# Out:
# Google_Dunkin_Reviews guardado en: Dunkin-Google-Reviews\Google_Dunkin_Reviews.parquet

# %% [markdown]
# - **MANIPULACIÓN DE DATOS NULOS.**

# %%
starbucks_reviews = pd.read_parquet('Starbucks-Google-Reviews/Google_Starbucks_Reviews.parquet')

# %%
starbucks_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313886 entries, 0 to 313885
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name_x            313886 non-null  object
#  1   address           313886 non-null  object
#  2   gmap_id           313886 non-null  object
#  3   description       309360 non-null  object
#  4   latitude          313886 non-null  float64
#  5   longitude         313886 non-null  float64
#  6   category          313886 non-null  object
#  7   avg_rating        313886 non-null  float64
#  8   num_of_reviews    313886 non-null  int64
#  9   price             310002 non-null  object
#  10  hours             294788 non-null  object
#  11  MISC              313858 non-null  object
#  12  state             294880 non-null  object
#  13  relative_results  297560 non-null  object
#  14  url               313886 non-null  object
#  15  user_id           313886 non-null  object
#  16  name_y            313886 non-null  object
#  17  time              313886 non-null  int64
#  18  rating            313886 non-null  int64
#  19  text              150284 non-null  object
#  20  pics              5744 non-null    object
#  21  resp              84 non-null      object
# dtypes: float64(3), int64(3), object(16)
# memory usage: 52.7+ MB

# %%
starbucks_reviews.isnull().sum()
# Out:
# name_x                   0
# address                  0
# gmap_id                  0
# description           4526
# latitude                 0
# longitude                0
# category                 0
# avg_rating               0
# num_of_reviews           0
# price                 3884
# hours                19098
# MISC                    28
# state                19006
# relative_results     16326
# url                      0
# user_id                  0
# name_y                   0
# time                     0
# rating                   0
# text                163602
# pics                308142
# resp                313802
# dtype: int64

# %% [markdown]
# -Se eliminan las columnas que tienen una cantidad relevante de nulos, en este caso "pics" y "resp".

# %%
starbucks_reviews = starbucks_reviews.drop(columns=['pics', 'resp'])
print('Columnas pics y resp han sido eliminadas.')
# Out:
# Columnas pics y resp han sido eliminadas.

# %% [markdown]
# - **TRANSFORMACIÓN DE COLUMNAS**

# %% [markdown]
# -Le cambiamos el nombre a la columna "state" por "open-close".

# %%
# Rename the column 'state' to 'open-close'
starbucks_reviews = starbucks_reviews.rename(columns={'state': 'open-close'})
print('La columna state ha sido renombrado como open-close.')
# Out:
# La columna state ha sido renombrado como open-close.

# %% [markdown]
# -Creamos una nueva columna llamada "state" con las siglas de cada estado.

# %%
#Lista de abreviaturas estatales
state_abbreviations = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'DC']

# Función para extraer la abreviatura del estado de "address"
def extract_state(address):
    for state in state_abbreviations:
        if state in address:
            return state
    return None

# Aplicar la función para crear la nueva columna
starbucks_reviews['state'] = starbucks_reviews['address'].apply(extract_state)

# %%
null_count = starbucks_reviews['state'].isnull().sum()
print('Cantidad de valores nulos en la columna state:', null_count)
# Out:
# Cantidad de valores nulos en la columna state: 76

# %%
# Filtrar el dataframe para mostrar las filas donde 'state' es nulo
df_nulos = starbucks_reviews[starbucks_reviews['state'].isnull()]

# Mostrar el head del dataframe filtrado
df_nulos.head()
# Out:
#            name_x                                      address  \
# 152391  Starbucks  Starbucks, 5296 Kings Plaza Unit 0K2, 11234
# 152392  Starbucks  Starbucks, 5296 Kings Plaza Unit 0K2, 11234
# 152393  Starbucks  Starbucks, 5296 Kings Plaza Unit 0K2, 11234
# 152394  Starbucks  Starbucks, 5296 Kings Plaza Unit 0K2, 11234
# 152395  Starbucks  Starbucks, 5296 Kings Plaza Unit 0K2, 11234
#
#                                       gmap_id  \
# 152391  0x89c25cbb98d8d5a5:0xe877a4885703cf3b
# 152392  0x89c25cbb98d8d5a5:0xe877a4885703cf3b
# 152393  0x89c25cbb98d8d5a5:0xe877a4885703cf3b
# 152394  0x89c25cbb98d8d5a5:0xe877a4885703cf3b
# 152395  0x89c25cbb98d8d5a5:0xe877a4885703cf3b
#
#                                               description   latitude  \
# 152391  Seattle-based coffeehouse chain known for its ...  40.610002
# 152392  Seattle-based coffeehouse chain known for its ...  40.610002
# 152393  Seattle-based coffeehouse chain known for its ...  40.610002
# 152394  Seattle-based coffeehouse chain known for its ...  40.610002
# 152395  Seattle-based coffeehouse chain known for its ...  40.610002
#
#         longitude                                           category  \
# 152391  -73.92086  [Coffee shop, Breakfast restaurant, Cafe, Coff...
# 152392  -73.92086  [Coffee shop, Breakfast restaurant, Cafe, Coff...
# 152393  -73.92086  [Coffee shop, Breakfast restaurant, Cafe, Coff...
# 152394  -73.92086  [Coffee shop, Breakfast restaurant, Cafe, Coff...
# 152395  -73.92086  [Coffee shop, Breakfast restaurant, Cafe, Coff...
#
#         avg_rating  num_of_reviews price  ...  \
# 152391         3.9              48    $$  ...
# 152392         3.9              48    $$  ...
# 152393         3.9              48    $$  ...
# 152394         3.9              48    $$  ...
# 152395         3.9              48    $$  ...
#
#                                                      MISC open-close  \
# 152391  {'Accessibility': ['Wheelchair accessible entr...       None
# 152392  {'Accessibility': ['Wheelchair accessible entr...       None
# 152393  {'Accessibility': ['Wheelchair accessible entr...       None
# 152394  {'Accessibility': ['Wheelchair accessible entr...       None
# 152395  {'Accessibility': ['Wheelchair accessible entr...       None
#
#                                          relative_results  \
# 152391  [0x89c25be97857f285:0x408adc5000c63fc, 0x89c24...
# 152392  [0x89c25be97857f285:0x408adc5000c63fc, 0x89c24...
# 152393  [0x89c25be97857f285:0x408adc5000c63fc, 0x89c24...
# 152394  [0x89c25be97857f285:0x408adc5000c63fc, 0x89c24...
# 152395  [0x89c25be97857f285:0x408adc5000c63fc, 0x89c24...
#
#                                                       url  \
# 152391  https://www.google.com/maps/place//data=!4m2!3...
# 152392  https://www.google.com/maps/place//data=!4m2!3...
# 152393  https://www.google.com/maps/place//data=!4m2!3...
# 152394  https://www.google.com/maps/place//data=!4m2!3...
# 152395  https://www.google.com/maps/place//data=!4m2!3...
#
#                       user_id         name_y           time  rating  \
# 152391  109252223292842956988    AliciaRenee  1604233934274       5
# 152392  109865412095765831400   Tricia Bless  1600725466674       4
# 152393  108245242730935605788    Yehuda Rand  1604267585104       5
# 152394  105773100329086681291   Chris Podvin  1568695752561       3
# 152395  109941687183369723471  Sinatra Young  1570840574349       5
#
#                                                      text state
# 152391  Quick stop and shop Starbucks. My Chai tea was...  None
# 152392              Staff is friendly. Food is expensive.  None
# 152393                                      Fast and easy  None
# 152394  Need more Saturday staff. Need some kind of ai...  None
# 152395                          Fast service polite staff  None
#
# [5 rows x 21 columns]

# %%
starbucks_reviews.head()
# Out:
#       name_x                                            address  \
# 0  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 1  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 2  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 3  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 4  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
#
#                                  gmap_id  \
# 0  0x88891beed225fed1:0x3c63ad3e69972d22
# 1  0x88891beed225fed1:0x3c63ad3e69972d22
# 2  0x88891beed225fed1:0x3c63ad3e69972d22
# 3  0x88891beed225fed1:0x3c63ad3e69972d22
# 4  0x88891beed225fed1:0x3c63ad3e69972d22
#
#                                          description   latitude  longitude  \
# 0  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 1  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 2  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 3  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 4  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
#
#                                           category  avg_rating  \
# 0  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 1  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 2  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 3  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 4  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
#
#    num_of_reviews price  ...  \
# 0              18    $$  ...
# 1              18    $$  ...
# 2              18    $$  ...
# 3              18    $$  ...
# 4              18    $$  ...
#
#                                                 MISC           open-close  \
# 0  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 1  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 2  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 4  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
#
#                                     relative_results  \
# 0  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 1  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 2  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 3  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 4  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
#
#                                                  url                user_id  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  100107003653040726165
# 1  https://www.google.com/maps/place//data=!4m2!3...  108921061266588850634
# 2  https://www.google.com/maps/place//data=!4m2!3...  115087327175786879005
# 3  https://www.google.com/maps/place//data=!4m2!3...  103797448577708424762
# 4  https://www.google.com/maps/place//data=!4m2!3...  104674782787422072897
#
#             name_y           time  rating  \
# 0   Jacob McCalpin  1505996531691       5
# 1           Alex Z  1538579468609       2
# 2   James Drummond  1557117732370       1
# 3  Matthew Pearson  1555686635302       1
# 4       Craig Winn  1534647989256       5
#
#                                                 text state
# 0  Chanel is the greatest barista of all time. I'...    AL
# 1  The food is always warm and delicious but the ...    AL
# 2  The location is a franchise of sorts operated ...    AL
# 3  Go to the one in Sterne. This place is a mess....    AL
# 4                       Open early and well staffed.    AL
#
# [5 rows x 21 columns]

# %% [markdown]
# - **CONVERSIÓN DE TIPOS DE DATOS.**

# %% [markdown]
# -Convertimos la columna "time" a valores reales de fecha y hora.

# %%
import datetime
import pandas as pd

# Función para convertir timestamp en milisegundos a formato legible
def convertir_timestamp(timestamp_ms):
    if pd.isna(timestamp_ms):
        return None
    try:
        timestamp_s = float(timestamp_ms) / 1000
        date_time = datetime.datetime.fromtimestamp(timestamp_s)
        return date_time.strftime('%Y-%m-%d %H:%M:%S')
    except Exception as e:
        print(f"Error converting timestamp: {timestamp_ms}, error: {e}")
        return None

# Mostrar los primeros valores de la columna 'time' antes de la conversión
print(starbucks_reviews['time'].head())

# Convertir la columna 'time' a tipo numérico
starbucks_reviews['time'] = pd.to_numeric(starbucks_reviews['time'], errors='coerce')

# Aplicar la función a la columna 'time'
starbucks_reviews['time'] = starbucks_reviews['time'].apply(convertir_timestamp)

# Mostrar el head del dataframe para verificar la conversión
starbucks_reviews.head()
# Out:
# 0    1505996531691
# 1    1538579468609
# 2    1557117732370
# 3    1555686635302
# 4    1534647989256
# Name: time, dtype: int64
#       name_x                                            address  \
# 0  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 1  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 2  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 3  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 4  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
#
#                                  gmap_id  \
# 0  0x88891beed225fed1:0x3c63ad3e69972d22
# 1  0x88891beed225fed1:0x3c63ad3e69972d22
# 2  0x88891beed225fed1:0x3c63ad3e69972d22
# 3  0x88891beed225fed1:0x3c63ad3e69972d22
# 4  0x88891beed225fed1:0x3c63ad3e69972d22
#
#                                          description   latitude  longitude  \
# 0  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 1  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 2  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 3  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 4  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
#
#                                           category  avg_rating  \
# 0  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 1  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 2  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 3  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 4  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
#
#    num_of_reviews price  ...  \
# 0              18    $$  ...
# 1              18    $$  ...
# 2              18    $$  ...
# 3              18    $$  ...
# 4              18    $$  ...
#
#                                                 MISC           open-close  \
# 0  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 1  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 2  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 4  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
#
#                                     relative_results  \
# 0  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 1  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 2  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 3  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 4  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
#
#                                                  url                user_id  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  100107003653040726165
# 1  https://www.google.com/maps/place//data=!4m2!3...  108921061266588850634
# 2  https://www.google.com/maps/place//data=!4m2!3...  115087327175786879005
# 3  https://www.google.com/maps/place//data=!4m2!3...  103797448577708424762
# 4  https://www.google.com/maps/place//data=!4m2!3...  104674782787422072897
#
#             name_y                 time rating  \
# 0   Jacob McCalpin  2017-09-21 09:22:11      5
# 1           Alex Z  2018-10-03 12:11:08      2
# 2   James Drummond  2019-05-06 01:42:12      1
# 3  Matthew Pearson  2019-04-19 12:10:35      1
# 4       Craig Winn  2018-08-19 00:06:29      5
#
#                                                 text state
# 0  Chanel is the greatest barista of all time. I'...    AL
# 1  The food is always warm and delicious but the ...    AL
# 2  The location is a franchise of sorts operated ...    AL
# 3  Go to the one in Sterne. This place is a mess....    AL
# 4                       Open early and well staffed.    AL
#
# [5 rows x 21 columns]

# %% [markdown]
# -Analizamos la columna "price" porque parece tener valores irrelevantes.

# %%
# Contar cuántas veces se repite el valor '$$' en la columna 'price' sin nada extra
count_exact_dollar_signs = starbucks_reviews[starbucks_reviews['price'] == '$$'].shape[0]

# Mostrar el resultado
print('El valor $$ se repite', count_exact_dollar_signs, 'veces en la columna price sin nada extra')
# Out:
# El valor $$ se repite 242892 veces en la columna price sin nada extra

# %%
# Mostrar los valores únicos en la columna 'price' que no sean '$$'
unique_prices_not_dollar = starbucks_reviews['price'].unique()
unique_prices_not_dollar = [price for price in unique_prices_not_dollar if price != '$$']

# Mostrar los primeros valores únicos que no sean '$$'
print(unique_prices_not_dollar[:10])
# Out:
# ['₩₩', None, '₩']

# %%
# Eliminar la columna 'price' del dataframe
starbucks_reviews.drop(columns=['price'], inplace=True)

# %%
starbucks_reviews.head()
# Out:
#       name_x                                            address  \
# 0  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 1  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 2  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 3  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
# 4  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...
#
#                                  gmap_id  \
# 0  0x88891beed225fed1:0x3c63ad3e69972d22
# 1  0x88891beed225fed1:0x3c63ad3e69972d22
# 2  0x88891beed225fed1:0x3c63ad3e69972d22
# 3  0x88891beed225fed1:0x3c63ad3e69972d22
# 4  0x88891beed225fed1:0x3c63ad3e69972d22
#
#                                          description   latitude  longitude  \
# 0  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 1  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 2  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 3  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
# 4  Seattle-based coffeehouse chain known for its ...  33.501601 -86.807263
#
#                                           category  avg_rating  \
# 0  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 1  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 2  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 3  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
# 4  [Coffee shop, Cafe, Coffee store, Espresso bar]         2.6
#
#    num_of_reviews                                              hours  \
# 0              18  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 1              18  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 2              18  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 3              18  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 4              18  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
#
#                                                 MISC           open-close  \
# 0  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 1  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 2  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 4  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
#
#                                     relative_results  \
# 0  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 1  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 2  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 3  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 4  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
#
#                                                  url                user_id  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  100107003653040726165
# 1  https://www.google.com/maps/place//data=!4m2!3...  108921061266588850634
# 2  https://www.google.com/maps/place//data=!4m2!3...  115087327175786879005
# 3  https://www.google.com/maps/place//data=!4m2!3...  103797448577708424762
# 4  https://www.google.com/maps/place//data=!4m2!3...  104674782787422072897
#
#             name_y                 time  rating  \
# 0   Jacob McCalpin  2017-09-21 09:22:11       5
# 1           Alex Z  2018-10-03 12:11:08       2
# 2   James Drummond  2019-05-06 01:42:12       1
# 3  Matthew Pearson  2019-04-19 12:10:35       1
# 4       Craig Winn  2018-08-19 00:06:29       5
#
#                                                 text state
# 0  Chanel is the greatest barista of all time. I'...    AL
# 1  The food is always warm and delicious but the ...    AL
# 2  The location is a franchise of sorts operated ...    AL
# 3  Go to the one in Sterne. This place is a mess....    AL
# 4                       Open early and well staffed.    AL

# %% [markdown]
# -Renombramos las columnas "name_x" por "name" y "name_y" por "user_name"

# %%
starbucks_reviews.rename(columns={'name_x': 'name', 'name_y': 'user_name'}, inplace=True)

# %% [markdown]
# -Reordenamos las columnas.

# %%
ordered_columns = ['name', 'address','state', 'description', 'category', 'user_id', 'user_name', 'rating', 'avg_rating', 'num_of_reviews', 'time', 'text', 'latitude', 'longitude']
remaining_columns = [col for col in starbucks_reviews.columns if col not in ordered_columns]
new_column_order = ordered_columns + remaining_columns

starbucks_reviews = starbucks_reviews[new_column_order]
print('Columns reordered successfully.')
starbucks_reviews.head()
# Out:
# Columns reordered successfully.
#         name                                            address state  \
# 0  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 1  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 2  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 3  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 4  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
#
#                                          description  \
# 0  Seattle-based coffeehouse chain known for its ...
# 1  Seattle-based coffeehouse chain known for its ...
# 2  Seattle-based coffeehouse chain known for its ...
# 3  Seattle-based coffeehouse chain known for its ...
# 4  Seattle-based coffeehouse chain known for its ...
#
#                                           category                user_id  \
# 0  [Coffee shop, Cafe, Coffee store, Espresso bar]  100107003653040726165
# 1  [Coffee shop, Cafe, Coffee store, Espresso bar]  108921061266588850634
# 2  [Coffee shop, Cafe, Coffee store, Espresso bar]  115087327175786879005
# 3  [Coffee shop, Cafe, Coffee store, Espresso bar]  103797448577708424762
# 4  [Coffee shop, Cafe, Coffee store, Espresso bar]  104674782787422072897
#
#          user_name  rating  avg_rating  num_of_reviews                time  \
# 0   Jacob McCalpin       5         2.6              18 2017-09-21 09:22:11
# 1           Alex Z       2         2.6              18 2018-10-03 12:11:08
# 2   James Drummond       1         2.6              18 2019-05-06 01:42:12
# 3  Matthew Pearson       1         2.6              18 2019-04-19 12:10:35
# 4       Craig Winn       5         2.6              18 2018-08-19 00:06:29
#
#                                                 text   latitude  longitude  \
# 0  Chanel is the greatest barista of all time. I'...  33.501601 -86.807263
# 1  The food is always warm and delicious but the ...  33.501601 -86.807263
# 2  The location is a franchise of sorts operated ...  33.501601 -86.807263
# 3  Go to the one in Sterne. This place is a mess....  33.501601 -86.807263
# 4                       Open early and well staffed.  33.501601 -86.807263
#
#                                  gmap_id  \
# 0  0x88891beed225fed1:0x3c63ad3e69972d22
# 1  0x88891beed225fed1:0x3c63ad3e69972d22
# 2  0x88891beed225fed1:0x3c63ad3e69972d22
# 3  0x88891beed225fed1:0x3c63ad3e69972d22
# 4  0x88891beed225fed1:0x3c63ad3e69972d22
#
#                                                hours  \
# 0  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 1  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 2  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 3  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 4  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
#
#                                                 MISC           open-close  \
# 0  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 1  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 2  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 4  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
#
#                                     relative_results  \
# 0  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 1  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 2  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 3  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 4  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# -Verificar que todas las columnas tengan el tipo de dato correcto.

# %%
# Convertir la columna 'time' a datetime
# Asegurarse de que 'latitude' y 'longitude' sean floats
# Asegurarse de que 'rating' y 'avg_rating' sean numéricos

# Convertir 'time' a datetime
try:
    starbucks_reviews['time'] = pd.to_datetime(starbucks_reviews['time'])
    print('Columna time convertida a datetime exitosamente.')
except Exception as e:
    print('Error al convertir time a datetime:', e)

# Convertir 'latitude' y 'longitude' a float
try:
    starbucks_reviews['latitude'] = starbucks_reviews['latitude'].astype(float)
    starbucks_reviews['longitude'] = starbucks_reviews['longitude'].astype(float)
    print('Columnas latitude y longitude convertidas a float exitosamente.')
except Exception as e:
    print('Error al convertir latitude y longitude a float:', e)

# Convertir 'rating' y 'avg_rating' a numérico
try:
    starbucks_reviews['rating'] = pd.to_numeric(starbucks_reviews['rating'], errors='coerce')
    starbucks_reviews['avg_rating'] = pd.to_numeric(starbucks_reviews['avg_rating'], errors='coerce')
    print('Columnas rating y avg_rating convertidas a numérico exitosamente.')
except Exception as e:
    print('Error al convertir rating y avg_rating a numérico:', e)

# Mostrar los tipos de datos para confirmar los cambios
print(starbucks_reviews.dtypes)
# Out:
# Columna time convertida a datetime exitosamente.
# Columnas latitude y longitude convertidas a float exitosamente.
# Columnas rating y avg_rating convertidas a numérico exitosamente.
# name                        object
# address                     object
# state                       object
# description                 object
# category                    object
# user_id                     object
# user_name                   object
# rating                       int64
# avg_rating                 float64
# num_of_reviews               int64
# time                datetime64[ns]
# text                        object
# latitude                   float64
# longitude                  float64
# gmap_id                     object
# hours                       object
# MISC                        object
# open-close                  object
# relative_results            object
# url                         object
# dtype: object

# %% [markdown]
# -Asegurarse de que los datos estén en un formato consistente

# %%
# Normalización de datos: Asegurarse de que las direcciones estén en un formato estándar
import re

# Función para normalizar direcciones
def normalize_address(address):
    address = address.strip().title()  # Eliminar espacios en blanco y poner en formato título
    address = re.sub(r'\s+', ' ', address)  # Reemplazar múltiples espacios por un solo espacio
    return address

# Aplicar la función de normalización a la columna 'address'
starbucks_reviews['address'] = starbucks_reviews['address'].apply(normalize_address)

print('Direcciones normalizadas exitosamente.')
starbucks_reviews['address'].head()
# Out:
# Direcciones normalizadas exitosamente.
# 0    Starbucks, 1400 University Blvd, Birmingham, A...
# 1    Starbucks, 1400 University Blvd, Birmingham, A...
# 2    Starbucks, 1400 University Blvd, Birmingham, A...
# 3    Starbucks, 1400 University Blvd, Birmingham, A...
# 4    Starbucks, 1400 University Blvd, Birmingham, A...
# Name: address, dtype: object

# %%
starbucks_reviews.head()
# Out:
#         name                                            address state  \
# 0  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 1  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 2  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 3  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
# 4  Starbucks  Starbucks, 1400 University Blvd, Birmingham, A...    AL
#
#                                          description  \
# 0  Seattle-based coffeehouse chain known for its ...
# 1  Seattle-based coffeehouse chain known for its ...
# 2  Seattle-based coffeehouse chain known for its ...
# 3  Seattle-based coffeehouse chain known for its ...
# 4  Seattle-based coffeehouse chain known for its ...
#
#                                           category                user_id  \
# 0  [Coffee shop, Cafe, Coffee store, Espresso bar]  100107003653040726165
# 1  [Coffee shop, Cafe, Coffee store, Espresso bar]  108921061266588850634
# 2  [Coffee shop, Cafe, Coffee store, Espresso bar]  115087327175786879005
# 3  [Coffee shop, Cafe, Coffee store, Espresso bar]  103797448577708424762
# 4  [Coffee shop, Cafe, Coffee store, Espresso bar]  104674782787422072897
#
#          user_name  rating  avg_rating  num_of_reviews                time  \
# 0   Jacob McCalpin       5         2.6              18 2017-09-21 09:22:11
# 1           Alex Z       2         2.6              18 2018-10-03 12:11:08
# 2   James Drummond       1         2.6              18 2019-05-06 01:42:12
# 3  Matthew Pearson       1         2.6              18 2019-04-19 12:10:35
# 4       Craig Winn       5         2.6              18 2018-08-19 00:06:29
#
#                                                 text   latitude  longitude  \
# 0  Chanel is the greatest barista of all time. I'...  33.501601 -86.807263
# 1  The food is always warm and delicious but the ...  33.501601 -86.807263
# 2  The location is a franchise of sorts operated ...  33.501601 -86.807263
# 3  Go to the one in Sterne. This place is a mess....  33.501601 -86.807263
# 4                       Open early and well staffed.  33.501601 -86.807263
#
#                                  gmap_id  \
# 0  0x88891beed225fed1:0x3c63ad3e69972d22
# 1  0x88891beed225fed1:0x3c63ad3e69972d22
# 2  0x88891beed225fed1:0x3c63ad3e69972d22
# 3  0x88891beed225fed1:0x3c63ad3e69972d22
# 4  0x88891beed225fed1:0x3c63ad3e69972d22
#
#                                                hours  \
# 0  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 1  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 2  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 3  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
# 4  [[Saturday, 10AM–1:30PM], [Sunday, Closed], [M...
#
#                                                 MISC           open-close  \
# 0  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 1  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 2  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 3  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
# 4  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 10AM
#
#                                     relative_results  \
# 0  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 1  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 2  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 3  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
# 4  [0x88891bc276c68cf9:0x669c302b2c5da34e, 0x8889...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
starbucks_reviews.to_parquet('Starbucks_reviews_limpio.parquet')
