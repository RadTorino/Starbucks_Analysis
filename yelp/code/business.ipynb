# %%
import pandas as pd

# %% [markdown]
# ### Limpíar, Filtrar y ordenar DF business de yealp - Trabajaremos con data de la cadena Starbucks

# %%
# Carga el archivo .parquet en un DataFrame de Pandas
df_business = pd.read_parquet('..//data//business.parquet')

# %%
# Filtrar el DataFrame para incluir solo las filas donde 'name' contiene la palabra 'Starbucks'
df_business = df_business[df_business['name'].str.contains('Starbucks', na=False)]

# %%
# Convertir la columna 'attributes' que contiene diccionarios en una serie de columnas
attributes_df = pd.json_normalize(df_business['attributes'])

# Concatenar el DataFrame original con el DataFrame de atributos
df_business = pd.concat([df_business.drop(columns=['attributes']), attributes_df], axis=1)

# %%
# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)
df_business.head(1)
# Out:
#                 business_id       name                address   city state  \
# 590  6_Zf2QsRHCH1RhbzA9inyw  Starbucks  8602 Hillsborough Ave  Tampa    LA
#
#     postal_code  latitude  longitude  stars  review_count  is_open  \
# 590       33615  27.99637 -82.580954    3.0          56.0      1.0
#
#              categories                                              hours  \
# 590  Coffee & Tea, Food  {'Friday': '5:30-21:0', 'Monday': '5:30-21:0',...
#
#      AcceptsInsurance  AgesAllowed Alcohol Ambience  BYOB  BYOBCorkage  \
# 590               NaN          NaN    None     None   NaN          NaN
#
#      BestNights BikeParking BusinessAcceptsBitcoin BusinessAcceptsCreditCards  \
# 590         NaN        True                   None                       True
#
#                                        BusinessParking ByAppointmentOnly  \
# 590  {'garage': False, 'street': False, 'validated'...              None
#
#     Caters  CoatCheck  Corkage  DietaryRestrictions DogsAllowed DriveThru  \
# 590  False        NaN      NaN                  NaN        None      None
#
#      GoodForDancing GoodForKids GoodForMeal  HairSpecializesIn  HappyHour  \
# 590             NaN        None        None                NaN        NaN
#
#     HasTV  Music NoiseLevel  Open24Hours OutdoorSeating RestaurantsAttire  \
# 590  None    NaN       None          NaN           True              None
#
#      RestaurantsCounterService RestaurantsDelivery RestaurantsGoodForGroups  \
# 590                        NaN                None                     None
#
#     RestaurantsPriceRange2 RestaurantsReservations RestaurantsTableService  \
# 590                      2                    None                    None
#
#     RestaurantsTakeOut  Smoking WheelchairAccessible     WiFi
# 590               True      NaN                 None  u'free'

# %%
# Redondear las coordenadas para simplificar el agrupamiento
df_business['rounded_latitude'] = df_business['latitude'].round(2)
df_business['rounded_longitude'] = df_business['longitude'].round(2)

# %%
# Crear la nueva columna 'sweetgreen_id' concatenando las columnas especificadas, separadas por un guion
df_business['starbucks_id'] = df_business['state'].astype(str) + '-' + \
                               df_business['rounded_latitude'].astype(str) + '-' + \
                               df_business['rounded_longitude'].astype(str)

# %%
# Eliminar las columnas 'rounded_latitude' y 'rounded_longitude'
df_business.drop(columns=['rounded_latitude', 'rounded_longitude'], inplace=True)

# %%
# Convertir la columna 'postal_code' a tipo numérico (float)
df_business['postal_code'] = pd.to_numeric(df_business['postal_code'], errors='coerce')

# %%
# Convertir a tipo int, ignorando los NaN
df_business['postal_code'] = df_business['postal_code'].astype('Int64')

# %%
# Verificar los primeros registros de la columna 'postal_code' después de la conversión
print(df_business['postal_code'].head())
# Out:
# 590     33615
# 613      <NA>
# 978      8077
# 1296    89501
# 1543     8012
# Name: postal_code, dtype: Int64

# %%
# Convertir la columna 'city' a tipo str
df_business['city'] = df_business['city'].astype(str)

# %%
# Eliminar las filas donde la columna 'name' tiene valores NaN
df_business = df_business.dropna(subset=['name'])

# %%
# Restablecer el índice
df_business = df_business.reset_index(drop=True)

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   business_id                 730 non-null    object
#  1   name                        730 non-null    object
#  2   address                     730 non-null    object
#  3   city                        730 non-null    object
#  4   state                       730 non-null    object
#  5   postal_code                 683 non-null    Int64
#  6   latitude                    730 non-null    float64
#  7   longitude                   730 non-null    float64
#  8   stars                       730 non-null    float64
#  9   review_count                730 non-null    float64
#  10  is_open                     730 non-null    float64
#  11  categories                  730 non-null    object
#  12  hours                       693 non-null    object
#  13  AcceptsInsurance            0 non-null      float64
#  14  AgesAllowed                 0 non-null      float64
#  15  Alcohol                     0 non-null      object
#  16  Ambience                    0 non-null      object
#  17  BYOB                        0 non-null      float64
#  18  BYOBCorkage                 0 non-null      float64
#  19  BestNights                  0 non-null      float64
#  20  BikeParking                 2 non-null      object
#  21  BusinessAcceptsBitcoin      0 non-null      object
#  22  BusinessAcceptsCreditCards  2 non-null      object
#  23  BusinessParking             2 non-null      object
#  24  ByAppointmentOnly           0 non-null      object
#  25  Caters                      2 non-null      object
#  26  CoatCheck                   0 non-null      float64
#  27  Corkage                     0 non-null      float64
#  28  DietaryRestrictions         0 non-null      float64
#  29  DogsAllowed                 1 non-null      object
#  30  DriveThru                   0 non-null      object
#  31  GoodForDancing              0 non-null      float64
#  32  GoodForKids                 0 non-null      object
#  33  GoodForMeal                 0 non-null      object
#  34  HairSpecializesIn           0 non-null      float64
#  35  HappyHour                   0 non-null      float64
#  36  HasTV                       0 non-null      object
#  37  Music                       0 non-null      float64
#  38  NoiseLevel                  0 non-null      object
#  39  Open24Hours                 0 non-null      float64
#  40  OutdoorSeating              2 non-null      object
#  41  RestaurantsAttire           0 non-null      object
#  42  RestaurantsCounterService   0 non-null      float64
#  43  RestaurantsDelivery         0 non-null      object
#  44  RestaurantsGoodForGroups    0 non-null      object
#  45  RestaurantsPriceRange2      2 non-null      object
#  46  RestaurantsReservations     0 non-null      object
#  47  RestaurantsTableService     0 non-null      object
#  48  RestaurantsTakeOut          2 non-null      object
#  49  Smoking                     0 non-null      float64
#  50  WheelchairAccessible        0 non-null      object
#  51  WiFi                        2 non-null      object
#  52  starbucks_id                730 non-null    object
# dtypes: Int64(1), float64(20), object(32)
# memory usage: 303.1+ KB

# %%
# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)
df_business.head(1)
# Out:
#               business_id       name                address   city state  \
# 0  6_Zf2QsRHCH1RhbzA9inyw  Starbucks  8602 Hillsborough Ave  Tampa    LA
#
#    postal_code  latitude  longitude  stars  review_count  is_open  \
# 0        33615  27.99637 -82.580954    3.0          56.0      1.0
#
#            categories                                              hours  \
# 0  Coffee & Tea, Food  {'Friday': '5:30-21:0', 'Monday': '5:30-21:0',...
#
#    AcceptsInsurance  AgesAllowed Alcohol Ambience  BYOB  BYOBCorkage  \
# 0               NaN          NaN    None     None   NaN          NaN
#
#    BestNights BikeParking BusinessAcceptsBitcoin BusinessAcceptsCreditCards  \
# 0         NaN        True                   None                       True
#
#                                      BusinessParking ByAppointmentOnly Caters  \
# 0  {'garage': False, 'street': False, 'validated'...              None  False
#
#    CoatCheck  Corkage  DietaryRestrictions DogsAllowed DriveThru  \
# 0        NaN      NaN                  NaN        None      None
#
#    GoodForDancing GoodForKids GoodForMeal  HairSpecializesIn  HappyHour HasTV  \
# 0             NaN        None        None                NaN        NaN  None
#
#    Music NoiseLevel  Open24Hours OutdoorSeating RestaurantsAttire  \
# 0    NaN       None          NaN           True              None
#
#    RestaurantsCounterService RestaurantsDelivery RestaurantsGoodForGroups  \
# 0                        NaN                None                     None
#
#   RestaurantsPriceRange2 RestaurantsReservations RestaurantsTableService  \
# 0                      2                    None                    None
#
#   RestaurantsTakeOut  Smoking WheelchairAccessible     WiFi    starbucks_id
# 0               True      NaN                 None  u'free'  LA-28.0--82.58

# %%
# Guardar el DataFrame como archivo Parquet
df_business.to_parquet('..//data//business.parquet')
